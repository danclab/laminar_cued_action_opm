# %%
import os
import numpy as np
from scipy.sparse import issparse
from scipy.signal import hilbert
from scipy.spatial import cKDTree, KDTree
import matplotlib.pyplot as plt
import nibabel as nib

from lameg.invert import coregister, invert_ebb, load_source_time_series, _load_inverse_components, _pad_or_trim_sensor_to_temp_projector, _restore_time_length
from lameg.laminar import model_comparison, roi_power_comparison
from lameg.surf import LayerSurfaceSet
from lameg.util import load_meg_sensor_data, get_fiducial_coords, ttest_rel_corrected
from lameg.viz import show_surface, verify_coregistration, color_map

import spm_standalone

# %%
spm = spm_standalone.initialize()

# %%
# %env SUBJECTS_DIR=/home/bonaiuto/laminar_cued_action_opm/OPM-LMN.260209/anat/fs/
# Out:
# env: SUBJECTS_DIR=/home/bonaiuto/laminar_cued_action_opm/OPM-LMN.260209/anat/fs/

# %%
subj_id = 'S01_CZZ'

# %%
def roi_power_comparison_multi(
    data_fnames,
    woi,
    baseline_woi,
    perc_thresh,
    surf_set,
    chunk_size=100,
    roi_idx=None,
    roi_mode="threshold",
):
    """
    Multi-file version of roi_power_comparison.

    Trials are pooled across files after source reconstruction.
    """

    valid_roi_modes = {"threshold", "restrict_threshold", "direct"}
    if roi_mode not in valid_roi_modes:
        raise ValueError(f"roi_mode must be one of {valid_roi_modes}, got {roi_mode!r}")

    if roi_mode in {"restrict_threshold", "direct"} and roi_idx is None:
        raise ValueError(f"roi_idx must be provided when roi_mode='{roi_mode}'")

    if isinstance(data_fnames, str):
        data_fnames = [data_fnames]

    if len(data_fnames) == 0:
        raise ValueError("data_fnames must contain at least one file")

    verts_per_surf = surf_set.get_vertices_per_layer()
    n_layers = surf_set.n_layers
    pial_vertices = np.arange(verts_per_surf)

    # ------------------------------------------------------------------
    # Load time axis from first file and verify compatibility
    # ------------------------------------------------------------------
    ts_v, time, _ = load_source_time_series(
        data_fnames[0],
        vertices=pial_vertices[:1],
    )
    base_t_idx = np.where((time >= baseline_woi[0]) & (time < baseline_woi[1]))[0]
    exp_t_idx = np.where((time >= woi[0]) & (time < woi[1]))[0]

    for data_fname in data_fnames[1:]:
        _, time_i, _ = load_source_time_series(
            data_fname,
            vertices=pial_vertices[:1],
        )
        if time_i.shape != time.shape or not np.allclose(time_i, time):
            raise ValueError(f"Time axis mismatch for file: {data_fname}")

    # ------------------------------------------------------------------
    # Core loader (multi-file pooling)
    # ------------------------------------------------------------------
    def load_and_compute_power_multi(vertices, chunk_size):
        vertices = np.asarray(vertices, dtype=int)
        if len(vertices) == 0:
            return np.zeros((0, 0)), np.zeros((0, 0))

        chunk_size = min(chunk_size, len(vertices))
        base_power_all = []
        exp_power_all = []

        for data_fname in data_fnames:
            ts_v, _, _ = load_source_time_series(
                data_fname,
                vertices=vertices[:1],
            )
            n_trials = ts_v.shape[2]

            base_incremental_power = np.zeros((len(vertices), n_trials))
            exp_incremental_power = np.zeros((len(vertices), n_trials))

            for start in range(0, len(vertices), chunk_size):
                end = min(start + chunk_size, len(vertices))
                vertex_slice = vertices[start:end]

                ts_chunk, _, _ = load_source_time_series(
                    data_fname,
                    vertices=vertex_slice,
                )
                envelope = np.abs(hilbert(ts_chunk, axis=1))

                base_power_chunk = np.squeeze(
                    np.mean(envelope[:, base_t_idx, :], axis=1)
                )
                exp_power_chunk = np.squeeze(
                    np.mean(envelope[:, exp_t_idx, :], axis=1)
                )

                if base_power_chunk.ndim == 1:
                    base_power_chunk = base_power_chunk[np.newaxis, :]
                if exp_power_chunk.ndim == 1:
                    exp_power_chunk = exp_power_chunk[np.newaxis, :]

                base_incremental_power[start:end, :] = base_power_chunk
                exp_incremental_power[start:end, :] = exp_power_chunk

                del ts_chunk, envelope, base_power_chunk, exp_power_chunk

            base_power_all.append(base_incremental_power)
            exp_power_all.append(exp_incremental_power)

        return (
            np.concatenate(base_power_all, axis=1),
            np.concatenate(exp_power_all, axis=1),
        )

    # ------------------------------------------------------------------
    # ROI logic
    # ------------------------------------------------------------------
    if roi_mode == "threshold":
        candidate_roi_idx = pial_vertices
    else:
        candidate_roi_idx = np.asarray(roi_idx, dtype=int)

    if roi_mode in {"threshold", "restrict_threshold"}:
        pial_candidate_idx = candidate_roi_idx
        white_candidate_idx = (n_layers - 1) * verts_per_surf + candidate_roi_idx

        pial_base_power, pial_exp_power = load_and_compute_power_multi(
            pial_candidate_idx,
            chunk_size,
        )
        white_base_power, white_exp_power = load_and_compute_power_multi(
            white_candidate_idx,
            chunk_size,
        )

        pial_power_change = pial_exp_power - pial_base_power
        white_power_change = white_exp_power - white_base_power

        pial_t_statistic, _, _ = ttest_rel_corrected(
            pial_power_change,
            axis=-1,
        )
        white_t_statistic, _, _ = ttest_rel_corrected(
            white_power_change,
            axis=-1,
        )

        pial_thresh = np.percentile(pial_t_statistic, perc_thresh)
        white_thresh = np.percentile(white_t_statistic, perc_thresh)

        keep_mask = (
            (pial_t_statistic > pial_thresh)
            | (white_t_statistic > white_thresh)
        )

        roi_idx = candidate_roi_idx[keep_mask]

        if roi_idx.size == 0:
            raise ValueError(
                "No vertices survived thresholding. "
                "Try lowering perc_thresh or checking roi_idx."
            )

        pial_roi_power_change = np.mean(
            pial_power_change[keep_mask, :], axis=0
        )
        white_roi_power_change = np.mean(
            white_power_change[keep_mask, :], axis=0
        )

    else:  # direct
        roi_idx = np.asarray(roi_idx, dtype=int)
        pial_roi_idx = roi_idx
        white_roi_idx = (n_layers - 1) * verts_per_surf + roi_idx

        pial_base_power, pial_exp_power = load_and_compute_power_multi(
            pial_roi_idx,
            min(len(pial_roi_idx), chunk_size),
        )
        white_base_power, white_exp_power = load_and_compute_power_multi(
            white_roi_idx,
            min(len(white_roi_idx), chunk_size),
        )

        pial_power_change = pial_exp_power - pial_base_power
        white_power_change = white_exp_power - white_base_power

        pial_roi_power_change = np.mean(pial_power_change, axis=0)
        white_roi_power_change = np.mean(white_power_change, axis=0)

    laminar_t_statistic, deg_of_freedom, laminar_p_value = ttest_rel_corrected(
        np.abs(pial_roi_power_change) - np.abs(white_roi_power_change),
        axis=-1,
    )

    return laminar_t_statistic, laminar_p_value, deg_of_freedom, roi_idx


def load_layer_power_multi(data_fnames, woi, baseline_woi, surf_set, roi_idx, chunk_size=100):
    """
    Multi-file version of load_layer_power.

    Pools trials across files after source reconstruction and returns the
    per-vertex t statistic for the pial ROI.

    Parameters
    ----------
    data_fnames : sequence of str
        Paths to MEG datasets.
    woi : tuple of float
        Experimental window of interest in ms, (start, end).
    baseline_woi : tuple of float
        Baseline window in ms, (start, end).
    surf_set : object
        Surface set object with get_vertices_per_layer() and n_layers.
    roi_idx : array_like
        Pial ROI vertex indices.
    chunk_size : int, optional
        Number of vertices per reconstruction chunk.

    Returns
    -------
    laminar_t_statistic : np.ndarray
        Per-vertex t statistic for pial experimental-minus-baseline power.
    """
    if isinstance(data_fnames, str):
        data_fnames = [data_fnames]

    if len(data_fnames) == 0:
        raise ValueError("data_fnames must contain at least one file")

    verts_per_surf = surf_set.get_vertices_per_layer()
    pial_vertices = np.arange(verts_per_surf)

    # Load time axis from first file and verify compatibility across files
    ts_v, time, _ = load_source_time_series(
        data_fnames[0],
        vertices=pial_vertices[:1],
    )
    base_t_idx = np.where((time >= baseline_woi[0]) & (time < baseline_woi[1]))[0]
    exp_t_idx = np.where((time >= woi[0]) & (time < woi[1]))[0]

    for data_fname in data_fnames[1:]:
        _, time_i, _ = load_source_time_series(
            data_fname,
            vertices=pial_vertices[:1],
        )
        if time_i.shape != time.shape or not np.allclose(time_i, time):
            raise ValueError(f"Time axis mismatch for file: {data_fname}")

    def load_and_compute_power_multi(vertices, chunk_size):
        vertices = np.asarray(vertices, dtype=int)
        if len(vertices) == 0:
            return np.zeros((0, 0)), np.zeros((0, 0))

        chunk_size = min(chunk_size, len(vertices))
        base_power_all = []
        exp_power_all = []

        for data_fname in data_fnames:
            ts_v, _, _ = load_source_time_series(
                data_fname,
                vertices=vertices[:1],
            )
            n_trials = ts_v.shape[2]

            base_incremental_power = np.zeros((len(vertices), n_trials))
            exp_incremental_power = np.zeros((len(vertices), n_trials))

            for start in range(0, len(vertices), chunk_size):
                end = min(start + chunk_size, len(vertices))
                vertex_slice = vertices[start:end]

                ts_chunk, _, _ = load_source_time_series(
                    data_fname,
                    vertices=vertex_slice,
                )
                envelope = np.abs(hilbert(ts_chunk, axis=1))

                base_power_chunk = np.squeeze(
                    np.mean(envelope[:, base_t_idx, :], axis=1)
                )
                exp_power_chunk = np.squeeze(
                    np.mean(envelope[:, exp_t_idx, :], axis=1)
                )

                if base_power_chunk.ndim == 1:
                    base_power_chunk = base_power_chunk[np.newaxis, :]
                if exp_power_chunk.ndim == 1:
                    exp_power_chunk = exp_power_chunk[np.newaxis, :]

                base_incremental_power[start:end, :] = base_power_chunk
                exp_incremental_power[start:end, :] = exp_power_chunk

                del ts_chunk, envelope, base_power_chunk, exp_power_chunk

            base_power_all.append(base_incremental_power)
            exp_power_all.append(exp_incremental_power)

        return (
            np.concatenate(base_power_all, axis=1),
            np.concatenate(exp_power_all, axis=1),
        )

    roi_idx = np.asarray(roi_idx, dtype=int)
    pial_roi_idx = roi_idx

    pial_base_power, pial_exp_power = load_and_compute_power_multi(
        pial_roi_idx,
        min(len(pial_roi_idx), chunk_size),
    )

    laminar_t_statistic, deg_of_freedom, laminar_p_value = ttest_rel_corrected(
        pial_exp_power - pial_base_power,
        axis=-1,
    )

    return laminar_t_statistic


def load_roi_power_ts_multi(data_fnames, baseline_woi, surf_set, roi_idx, chunk_size=100):
    """
    Multi-file version of load_roi_power_ts.

    Reconstructs baseline-corrected analytic-amplitude time series for pial and white
    matter ROI vertices, then concatenates trials across files.

    Parameters
    ----------
    data_fnames : sequence of str
        Paths to MEG datasets.
    baseline_woi : tuple of float
        Baseline window in ms, (start, end).
    surf_set : object
        Surface set object with get_vertices_per_layer() and n_layers.
    roi_idx : array_like
        Pial ROI vertex indices.
    chunk_size : int, optional
        Number of vertices per reconstruction chunk.

    Returns
    -------
    pial_exp_power_ts : np.ndarray
        Baseline-corrected pial analytic amplitude, shape
        (n_roi_vertices, n_time, pooled_trials).
    white_exp_power_ts : np.ndarray
        Baseline-corrected white analytic amplitude, shape
        (n_roi_vertices, n_time, pooled_trials).
    time : np.ndarray
        Time vector in ms.
    """
    if isinstance(data_fnames, str):
        data_fnames = [data_fnames]

    if len(data_fnames) == 0:
        raise ValueError("data_fnames must contain at least one file")

    verts_per_surf = surf_set.get_vertices_per_layer()

    # Load time axis from first file and verify compatibility across files
    ts_v, time, _ = load_source_time_series(
        data_fnames[0],
        vertices=[0],
    )
    base_t_idx = np.where((time >= baseline_woi[0]) & (time < baseline_woi[1]))[0]

    for data_fname in data_fnames[1:]:
        _, time_i, _ = load_source_time_series(
            data_fname,
            vertices=[0],
        )
        if time_i.shape != time.shape or not np.allclose(time_i, time):
            raise ValueError(f"Time axis mismatch for file: {data_fname}")

    def load_and_compute_power_multi(vertices, chunk_size):
        vertices = np.asarray(vertices, dtype=int)
        if len(vertices) == 0:
            return np.zeros((0, len(time), 0))

        chunk_size = min(chunk_size, len(vertices))
        ts_all = []

        for data_fname in data_fnames:
            ts_v, _, _ = load_source_time_series(
                data_fname,
                vertices=vertices[:1],
            )
            n_trials = ts_v.shape[2]

            exp_incremental_ts = np.zeros((len(vertices), len(time), n_trials))

            for start in range(0, len(vertices), chunk_size):
                end = min(start + chunk_size, len(vertices))
                vertex_slice = vertices[start:end]

                ts_chunk, _, _ = load_source_time_series(
                    data_fname,
                    vertices=vertex_slice,
                )
                envelope = np.abs(hilbert(ts_chunk, axis=1))

                base_power_chunk = np.mean(envelope[:, base_t_idx, :], axis=1)

                if base_power_chunk.ndim == 1:
                    base_power_chunk = base_power_chunk[np.newaxis, :]

                exp_incremental_ts[start:end, :, :] = (
                    envelope - base_power_chunk[:, np.newaxis, :]
                )

                del ts_chunk, envelope, base_power_chunk

            ts_all.append(exp_incremental_ts)

        return np.concatenate(ts_all, axis=2)

    roi_idx = np.asarray(roi_idx, dtype=int)
    pial_roi_idx = roi_idx
    white_roi_idx = verts_per_surf + roi_idx

    pial_exp_power_ts = load_and_compute_power_multi(
        pial_roi_idx,
        min(len(pial_roi_idx), chunk_size),
    )
    white_exp_power_ts = load_and_compute_power_multi(
        white_roi_idx,
        min(len(white_roi_idx), chunk_size),
    )

    return pial_exp_power_ts, white_exp_power_ts, time

# %%
surf_set_bilam = LayerSurfaceSet(subj_id, 2)

# %%
v1_roi_idx = surf_set_bilam.get_roi_idx(['V1_exvivo'], atlas='BA_exvivo')
print(v1_roi_idx.shape)
# Out:
# (1117,)

# %%
# Data file
data_file = os.path.join('/home/bonaiuto/laminar_cued_action_opm/OPM-LMN.260209/opm/proc',subj_id,f'spm_R1_epo.mat')
cam_view = [-0.267, 0.026, 0.003,
            0.001, 0.011, 0.014,
            -0.102,-0.191, 0.976]
plot = verify_coregistration(data_file, surf_set_bilam, camera_view=cam_view)
# Out:
# RMSE of rigid transformation between forward model mesh and surf_set mesh is 2.320303409310578e-17.
# If this is high, coregistration may not have been done using /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/multilayer.2.ds.link_vector.fixed.gii.
# Either run coregistration with this mesh, or change parameters to match the mesh coregistration was done with.
# Output()

# %%
cam_view=[50.00, -207.71, -118.80,
          60.23, 18.16, -47.44,
          0.00, -0.34, 0.94]

# %%
alpha_foi=[7,13]
alpha_base_woi=[1000+-1000,1000+0]
alpha_exp_woi=[1000+0, 1000+1000]

# %%
data_files = []
for run in range(5):
    run_id = f"R{run+1}"
    data_file = os.path.join(
        "/home/bonaiuto/laminar_cued_action_opm/OPM-LMN.260209/opm/proc",
        subj_id,
        f"spm_{run_id}_epo.mat",
    )
    data_files.append(data_file)

    invert_ebb(
        data_file,
        surf_set_bilam,
        foi=alpha_foi,
        patch_size=5,
        n_temp_modes=4,
        spm_instance=spm,
    )
# Out:
# Smoothing /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/multilayer.2.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '/home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat'
#
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using 0 spatial modes
#
# Preparing modes file  block 1 of 1 for 74 training and 0 test chans
#
#  saving spatial mode file /home/bonaiuto/laminar_opm/OPM-LMN.260209/opm/proc/S01_CZZ/spm_R1_epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
# Initialising batch system... done.
#
#
# ------------------------------------------------------------------------
# 06-Apr-2026 12:25:56 - Running job #1
# ------------------------------------------------------------------------
# 06-Apr-2026 12:25:56 - Running 'Source inversion, iterative'
# Auto selecting number of spatial modes
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm_R1_epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.6006    0.5557
#     0.0506    0.6511
#
#  - done
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using 49 spatial modesNumber of samples 1000
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 31.18 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...1.217214e+04 [+4.12]
#   ReML Iteration 2                      :        ...8.967297e+03 [+4.25]
#   ReML Iteration 3                      :        ...4.771473e+03 [+4.38]
#   ReML Iteration 4                      :        ...1.229894e+03 [+4.50]
#   ReML Iteration 5                      :        ...7.227465e+01 [+4.62]
#   ReML Iteration 6                      :        ...2.666545e-01 [+4.75]
#   ReML Iteration 7                      :        ...4.674219e-05 [+4.88]
# Inverting subject 1
#   ReML Iteration 1                      :        ...1.217214e+04 [+4.12]
#   ReML Iteration 2                      :        ...8.967297e+03 [+4.25]
#   ReML Iteration 3                      :        ...4.771473e+03 [+4.38]
#   ReML Iteration 4                      :        ...1.229894e+03 [+4.50]
#   ReML Iteration 5                      :        ...7.227465e+01 [+4.62]
#   ReML Iteration 6                      :        ...2.666545e-01 [+4.75]
#   ReML Iteration 7                      :        ...4.674219e-05 [+4.88]
# Percent variance explained 97.97 (30.55)
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 7
#           hpf: 13
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 0
#       PostMax: [65582x1 double]
#             A: [0x74 double]
#            Ip: [1x512 double]
#             M: [65582x49 double]
#             J: {[65582x4 double]}
#             L: [49x65582 double]
#            qC: [65582x1 double]
#         tempU: [48x48 double]
#             V: [48x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[49x74 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x178 double]
#            Ic: {[1x74 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x48 double]
#            ID: 244.2796
#             F: 9.2798e+05
#            R2: 97.9660
#            VE: 30.5451
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 7
#           hpf: 13
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 9.2798e+05
#       PostMax: [65582x1 double]
#             A: [0x74 double]
#            Ip: [1x512 double]
#             M: [65582x49 double]
#             J: {[65582x4 double]}
#             L: [49x65582 double]
#            qC: [65582x1 double]
#         tempU: [48x48 double]
#             V: [48x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[49x74 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x178 double]
#            Ic: {[1x74 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x48 double]
#            ID: 244.2796
#             F: 9.2798e+05
#            R2: 97.9660
#            VE: 30.5451
#
# 06-Apr-2026 12:26:16 - Done    'Source inversion, iterative'
# 06-Apr-2026 12:26:16 - Done
#
# Smoothing /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/multilayer.2.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '/home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat'
#
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using 0 spatial modes
#
# Preparing modes file  block 1 of 1 for 71 training and 0 test chans
#
#  saving spatial mode file /home/bonaiuto/laminar_opm/OPM-LMN.260209/opm/proc/S01_CZZ/spm_R2_epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
#
#
# ------------------------------------------------------------------------
# 06-Apr-2026 12:26:19 - Running job #1
# ------------------------------------------------------------------------
# 06-Apr-2026 12:26:19 - Running 'Source inversion, iterative'
# Auto selecting number of spatial modes
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm_R2_epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.6006    0.5557
#     0.0506    0.6511
#
#  - done
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using 44 spatial modesNumber of samples 1000
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 32.48 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...1.140177e+04 [+4.12]
#   ReML Iteration 2                      :        ...9.118833e+03 [+4.25]
#   ReML Iteration 3                      :        ...5.615493e+03 [+4.38]
#   ReML Iteration 4                      :        ...1.878737e+03 [+4.50]
#   ReML Iteration 5                      :        ...1.612972e+02 [+4.62]
#   ReML Iteration 6                      :        ...8.302253e-01 [+4.75]
#   ReML Iteration 7                      :        ...5.733259e-04 [+4.88]
# Inverting subject 1
#   ReML Iteration 1                      :        ...1.140177e+04 [+4.12]
#   ReML Iteration 2                      :        ...9.118833e+03 [+4.25]
#   ReML Iteration 3                      :        ...5.615493e+03 [+4.38]
#   ReML Iteration 4                      :        ...1.878737e+03 [+4.50]
#   ReML Iteration 5                      :        ...1.612972e+02 [+4.62]
#   ReML Iteration 6                      :        ...8.302253e-01 [+4.75]
#   ReML Iteration 7                      :        ...5.733259e-04 [+4.88]
# Percent variance explained 98.95 (32.14)
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 7
#           hpf: 13
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 0
#       PostMax: [65582x1 double]
#             A: [0x71 double]
#            Ip: [1x512 double]
#             M: [65582x44 double]
#             J: {[65582x4 double]}
#             L: [44x65582 double]
#            qC: [65582x1 double]
#         tempU: [48x48 double]
#             V: [48x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[44x71 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x178 double]
#            Ic: {[1x71 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x48 double]
#            ID: 246.3817
#             F: 8.3344e+05
#            R2: 98.9472
#            VE: 32.1389
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 7
#           hpf: 13
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 8.3344e+05
#       PostMax: [65582x1 double]
#             A: [0x71 double]
#            Ip: [1x512 double]
#             M: [65582x44 double]
#             J: {[65582x4 double]}
#             L: [44x65582 double]
#            qC: [65582x1 double]
#         tempU: [48x48 double]
#             V: [48x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[44x71 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x178 double]
#            Ic: {[1x71 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x48 double]
#            ID: 246.3817
#             F: 8.3344e+05
#            R2: 98.9472
#            VE: 32.1389
#
# 06-Apr-2026 12:26:37 - Done    'Source inversion, iterative'
# 06-Apr-2026 12:26:37 - Done
#
# Smoothing /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/multilayer.2.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '/home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat'
#
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using 0 spatial modes
#
# Preparing modes file  block 1 of 1 for 73 training and 0 test chans
#
#  saving spatial mode file /home/bonaiuto/laminar_opm/OPM-LMN.260209/opm/proc/S01_CZZ/spm_R3_epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
#
#
# ------------------------------------------------------------------------
# 06-Apr-2026 12:26:41 - Running job #1
# ------------------------------------------------------------------------
# 06-Apr-2026 12:26:41 - Running 'Source inversion, iterative'
# Auto selecting number of spatial modes
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm_R3_epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.6006    0.5557
#     0.0506    0.6511
#
#  - done
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using 46 spatial modesNumber of samples 1000
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 31.10 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...1.204195e+04 [+4.12]
#   ReML Iteration 2                      :        ...9.570005e+03 [+4.25]
#   ReML Iteration 3                      :        ...5.967264e+03 [+4.38]
#   ReML Iteration 4                      :        ...2.199185e+03 [+4.50]
#   ReML Iteration 5                      :        ...2.745174e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.988229e+00 [+4.75]
#   ReML Iteration 7                      :        ...6.187553e-04 [+4.88]
# Inverting subject 1
#   ReML Iteration 1                      :        ...1.204195e+04 [+4.12]
#   ReML Iteration 2                      :        ...9.570005e+03 [+4.25]
#   ReML Iteration 3                      :        ...5.967264e+03 [+4.38]
#   ReML Iteration 4                      :        ...2.199185e+03 [+4.50]
#   ReML Iteration 5                      :        ...2.745174e+02 [+4.62]
#   ReML Iteration 6                      :        ...3.988229e+00 [+4.75]
#   ReML Iteration 7                      :        ...6.187553e-04 [+4.88]
# Percent variance explained 99.05 (30.80)
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 7
#           hpf: 13
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 0
#       PostMax: [65582x1 double]
#             A: [0x73 double]
#            Ip: [1x512 double]
#             M: [65582x46 double]
#             J: {[65582x4 double]}
#             L: [46x65582 double]
#            qC: [65582x1 double]
#         tempU: [48x48 double]
#             V: [48x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[46x73 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x73 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x48 double]
#            ID: 282.0851
#             F: 8.7851e+05
#            R2: 99.0465
#            VE: 30.8035
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 7
#           hpf: 13
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 8.7851e+05
#       PostMax: [65582x1 double]
#             A: [0x73 double]
#            Ip: [1x512 double]
#             M: [65582x46 double]
#             J: {[65582x4 double]}
#             L: [46x65582 double]
#            qC: [65582x1 double]
#         tempU: [48x48 double]
#             V: [48x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[46x73 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x73 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x48 double]
#            ID: 282.0851
#             F: 8.7851e+05
#            R2: 99.0465
#            VE: 30.8035
#
# 06-Apr-2026 12:27:01 - Done    'Source inversion, iterative'
# 06-Apr-2026 12:27:01 - Done
#
# Smoothing /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/multilayer.2.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '/home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat'
#
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using 0 spatial modes
#
# Preparing modes file  block 1 of 1 for 72 training and 0 test chans
#
#  saving spatial mode file /home/bonaiuto/laminar_opm/OPM-LMN.260209/opm/proc/S01_CZZ/spm_R4_epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
# ------------------------------------------------------------------------
# 06-Apr-2026 12:27:04 - Running job #1
# ------------------------------------------------------------------------
# 06-Apr-2026 12:27:04 - Running 'Source inversion, iterative'
# Auto selecting number of spatial modes
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm_R4_epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.6006    0.5557
#     0.0506    0.6511
#
#  - done
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using 43 spatial modesNumber of samples 1000
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 28.99 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...1.107857e+04 [+4.12]
#   ReML Iteration 2                      :        ...8.711196e+03 [+4.25]
#   ReML Iteration 3                      :        ...5.253501e+03 [+4.38]
#   ReML Iteration 4                      :        ...1.763122e+03 [+4.50]
#   ReML Iteration 5                      :        ...1.740964e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.437974e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.145064e-04 [+4.88]
# Inverting subject 1
#   ReML Iteration 1                      :        ...1.107857e+04 [+4.12]
#   ReML Iteration 2                      :        ...8.711196e+03 [+4.25]
#   ReML Iteration 3                      :        ...5.253501e+03 [+4.38]
#   ReML Iteration 4                      :        ...1.763122e+03 [+4.50]
#   ReML Iteration 5                      :        ...1.740964e+02 [+4.62]
#   ReML Iteration 6                      :        ...1.437974e+00 [+4.75]
#   ReML Iteration 7                      :        ...1.145064e-04 [+4.88]
# Percent variance explained 99.12 (28.73)
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 7
#           hpf: 13
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 0
#       PostMax: [65582x1 double]
#             A: [0x72 double]
#            Ip: [1x512 double]
#             M: [65582x43 double]
#             J: {[65582x4 double]}
#             L: [43x65582 double]
#            qC: [65582x1 double]
#         tempU: [48x48 double]
#             V: [48x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[43x72 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x72 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x48 double]
#            ID: 254.6020
#             F: 8.2231e+05
#            R2: 99.1164
#            VE: 28.7327
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 7
#           hpf: 13
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 8.2231e+05
#       PostMax: [65582x1 double]
#             A: [0x72 double]
#            Ip: [1x512 double]
#             M: [65582x43 double]
#             J: {[65582x4 double]}
#             L: [43x65582 double]
#            qC: [65582x1 double]
#         tempU: [48x48 double]
#             V: [48x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[43x72 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x72 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x48 double]
#            ID: 254.6020
#             F: 8.2231e+05
#            R2: 99.1164
#            VE: 28.7327
#
# 06-Apr-2026 12:27:28 - Done    'Source inversion, iterative'
# 06-Apr-2026 12:27:28 - Done
#
# Smoothing /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/multilayer.2.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '/home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat'
#
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using 0 spatial modes
#
# Preparing modes file  block 1 of 1 for 70 training and 0 test chans
#
#  saving spatial mode file /home/bonaiuto/laminar_opm/OPM-LMN.260209/opm/proc/S01_CZZ/spm_R5_epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
#
#
# ------------------------------------------------------------------------
# 06-Apr-2026 12:27:32 - Running job #1
# ------------------------------------------------------------------------
# 06-Apr-2026 12:27:32 - Running 'Source inversion, iterative'
# Auto selecting number of spatial modes
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm_R5_epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.6006    0.5557
#     0.0506    0.6511
#
#  - done
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using 41 spatial modesNumber of samples 1000
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 31.62 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...1.070739e+04 [+4.12]
#   ReML Iteration 2                      :        ...8.556137e+03 [+4.25]
#   ReML Iteration 3                      :        ...5.381504e+03 [+4.38]
#   ReML Iteration 4                      :        ...1.969557e+03 [+4.50]
#   ReML Iteration 5                      :        ...2.246514e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.203861e+00 [+4.75]
#   ReML Iteration 7                      :        ...6.990979e-04 [+4.88]
# Inverting subject 1
#   ReML Iteration 1                      :        ...1.070739e+04 [+4.12]
#   ReML Iteration 2                      :        ...8.556137e+03 [+4.25]
#   ReML Iteration 3                      :        ...5.381504e+03 [+4.38]
#   ReML Iteration 4                      :        ...1.969557e+03 [+4.50]
#   ReML Iteration 5                      :        ...2.246514e+02 [+4.62]
#   ReML Iteration 6                      :        ...2.203861e+00 [+4.75]
#   ReML Iteration 7                      :        ...6.990979e-04 [+4.88]
# Percent variance explained 99.01 (31.31)
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 7
#           hpf: 13
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 0
#       PostMax: [65582x1 double]
#             A: [0x70 double]
#            Ip: [1x512 double]
#             M: [65582x41 double]
#             J: {[65582x4 double]}
#             L: [41x65582 double]
#            qC: [65582x1 double]
#         tempU: [48x48 double]
#             V: [48x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[41x70 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x70 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x48 double]
#            ID: 233.8161
#             F: 7.8623e+05
#            R2: 99.0087
#            VE: 31.3060
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 7
#           hpf: 13
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 7.8623e+05
#       PostMax: [65582x1 double]
#             A: [0x70 double]
#            Ip: [1x512 double]
#             M: [65582x41 double]
#             J: {[65582x4 double]}
#             L: [41x65582 double]
#            qC: [65582x1 double]
#         tempU: [48x48 double]
#             V: [48x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[41x70 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x70 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x48 double]
#            ID: 233.8161
#             F: 7.8623e+05
#            R2: 99.0087
#            VE: 31.3060
#
# 06-Apr-2026 12:27:46 - Done    'Source inversion, iterative'
# 06-Apr-2026 12:27:46 - Done

# %%
laminar_t_statistic, laminar_p_value, df, alpha_roi_idx = roi_power_comparison_multi(
    data_files,
    alpha_exp_woi,
    alpha_base_woi,
    80,
    surf_set_bilam,
    roi_idx=v1_roi_idx,
    roi_mode="restrict_threshold",
    chunk_size=100
)
print(f"t({df})={laminar_t_statistic}, p={laminar_p_value}")

alpha_pial_power = load_layer_power_multi(
    data_files, 
    alpha_exp_woi,
    alpha_base_woi, 
    surf_set_bilam,
    alpha_roi_idx,
    chunk_size=100
)
alpha_layer_power=np.zeros(surf_set_bilam.get_vertices_per_layer())
alpha_layer_power[alpha_roi_idx]=alpha_pial_power
v_colors, c_map = color_map(
    alpha_layer_power, 
    "RdYlBu_r", 
    -np.max(np.abs(alpha_layer_power)), 
    np.max(np.abs(alpha_layer_power))
)
v_colors_thresh = np.zeros((v_colors.shape[0], 4))
v_colors_thresh[:, :3] = v_colors
v_colors_thresh[np.abs(alpha_layer_power)>0, -1] = 255
plot = show_surface(
    surf_set_bilam,
    layer_name="inflated",
    stage="ds",
    vertex_colors=v_colors_thresh,
    info=True,
    camera_view=cam_view
)

alpha_pial_bc_power, alpha_white_bc_power, time = load_roi_power_ts_multi(
    data_files, 
    alpha_base_woi, 
    surf_set_bilam, 
    alpha_roi_idx, 
    chunk_size=100
)
col_r = plt.cm.cool(np.linspace(0, 1, num=2))
roi_pial_bc_power = np.mean(alpha_pial_bc_power, axis=0)
roi_white_bc_power = np.mean(alpha_white_bc_power, axis=0)
m_pial_bc_power = np.mean(roi_pial_bc_power, axis=-1)
m_white_bc_power = np.mean(roi_white_bc_power, axis=-1)
plt.figure()
plt.plot(time-1000, m_pial_bc_power, label="pial", color=col_r[0, :])
plt.plot(time-1000, m_white_bc_power, label="white matter", color=col_r[1, :])
plt.axvline(0, color="k", linestyle="--")
plt.axvline(2000, color="k", linestyle="--")
plt.axvline(2500, color="k", linestyle="--")
plt.xlim([-1000, 3000])
plt.xlabel("Time (ms)")
plt.ylabel("$\\Delta$ power")
plt.legend()

exp_t_idx = (time >= alpha_exp_woi[0]) & (time <= alpha_exp_woi[1])
alpha_t_stats=[]
for x in range(len(alpha_roi_idx)):
    roi_pial_bc = alpha_pial_bc_power[x, :, :]
    roi_pial_bc = np.mean(roi_pial_bc[exp_t_idx, :], axis=0)

    roi_white_bc = alpha_white_bc_power[x, :, :]
    roi_white_bc = np.mean(roi_white_bc[exp_t_idx, :], axis=0)

    v_t_stat, v_dof, v_p = ttest_rel_corrected(
        np.abs(roi_pial_bc) - np.abs(roi_white_bc),
        axis=-1,
    )
    alpha_t_stats.append(v_t_stat)
plt.figure()
plt.hist(alpha_t_stats, 50, density=True)
plt.axvline(0, color="k", linestyle="--")
xl = plt.xlim()
xlim = [-np.max(np.abs(xl)), np.max(np.abs(xl))]
plt.xlim(xlim)
plt.xlabel("t statistic (pial-white)")
plt.ylabel("Density")
# Out:
# t(895)=-10.615712943831527, p=7.066574593472649e-25
# Output()
# 32791 vertices
# /home/bonaiuto/miniconda3/envs/lameg_dev/lib/python3.7/site-packages/lameg/util.py:623: RuntimeWarning: invalid value encountered in double_scalars
#   tval = (xmean - 0) / ser
# Text(0, 0.5, 'Density')

# %%
gamma_foi=[60,90]
gamma_base_woi=[1000+-1000,1000+0]
gamma_exp_woi=[1000+0, 1000+500]

# %%
data_files = []
for run in range(5):
    run_id = f"R{run+1}"
    data_file = os.path.join(
        "/home/bonaiuto/laminar_cued_action_opm/OPM-LMN.260209/opm/proc",
        subj_id,
        f"spm_{run_id}_epo.mat",
    )
    data_files.append(data_file)

    invert_ebb(
        data_file,
        surf_set_bilam,
        foi=gamma_foi,
        patch_size=5,
        n_temp_modes=4,
        spm_instance=spm,
    )
# Out:
# Smoothing /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/multilayer.2.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '/home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat'
#
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using 0 spatial modes
#
# Preparing modes file  block 1 of 1 for 74 training and 0 test chans
#
#  saving spatial mode file /home/bonaiuto/laminar_opm/OPM-LMN.260209/opm/proc/S01_CZZ/spm_R1_epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
#
#
# ------------------------------------------------------------------------
# 06-Apr-2026 13:04:16 - Running job #1
# ------------------------------------------------------------------------
# 06-Apr-2026 13:04:16 - Running 'Source inversion, iterative'
# Auto selecting number of spatial modes
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm_R1_epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.6006    0.5557
#     0.0506    0.6511
#
#  - done
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using 49 spatial modesNumber of samples 1000
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 2.61 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.671947e+03 [+4.12]
#   ReML Iteration 2                      :        ...3.535148e+02 [+4.25]
#   ReML Iteration 3                      :        ...2.237692e+01 [+4.38]
#   ReML Iteration 4                      :        ...3.773413e-01 [+4.50]
#   ReML Iteration 5                      :        ...2.280394e-03 [+4.62]
# Inverting subject 1
#   ReML Iteration 1                      :        ...2.671947e+03 [+4.12]
#   ReML Iteration 2                      :        ...3.535148e+02 [+4.25]
#   ReML Iteration 3                      :        ...2.237692e+01 [+4.38]
#   ReML Iteration 4                      :        ...3.773413e-01 [+4.50]
#   ReML Iteration 5                      :        ...2.280394e-03 [+4.62]
# Percent variance explained 28.36 (0.74)
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 60
#           hpf: 90
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 0
#       PostMax: [65582x1 double]
#             A: [0x74 double]
#            Ip: [1x512 double]
#             M: [65582x49 double]
#             J: {[65582x4 double]}
#             L: [49x65582 double]
#            qC: [65582x1 double]
#         tempU: [240x240 double]
#             V: [240x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[49x74 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x178 double]
#            Ic: {[1x74 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x240 double]
#            ID: 390.6820
#             F: 9.8288e+05
#            R2: 28.3597
#            VE: 0.7395
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 60
#           hpf: 90
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 9.8288e+05
#       PostMax: [65582x1 double]
#             A: [0x74 double]
#            Ip: [1x512 double]
#             M: [65582x49 double]
#             J: {[65582x4 double]}
#             L: [49x65582 double]
#            qC: [65582x1 double]
#         tempU: [240x240 double]
#             V: [240x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[49x74 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x178 double]
#            Ic: {[1x74 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x240 double]
#            ID: 390.6820
#             F: 9.8288e+05
#            R2: 28.3597
#            VE: 0.7395
#
# 06-Apr-2026 13:04:35 - Done    'Source inversion, iterative'
# 06-Apr-2026 13:04:35 - Done
#
# Smoothing /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/multilayer.2.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '/home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat'
#
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using 0 spatial modes
#
# Preparing modes file  block 1 of 1 for 71 training and 0 test chans
#
#  saving spatial mode file /home/bonaiuto/laminar_opm/OPM-LMN.260209/opm/proc/S01_CZZ/spm_R2_epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
#
#
# ------------------------------------------------------------------------
# 06-Apr-2026 13:04:38 - Running job #1
# ------------------------------------------------------------------------
# 06-Apr-2026 13:04:38 - Running 'Source inversion, iterative'
# Auto selecting number of spatial modes
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm_R2_epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.6006    0.5557
#     0.0506    0.6511
#
#  - done
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using 44 spatial modesNumber of samples 1000
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 3.11 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.459539e+03 [+4.12]
#   ReML Iteration 2                      :        ...2.924548e+02 [+4.25]
#   ReML Iteration 3                      :        ...1.169796e+01 [+4.38]
#   ReML Iteration 4                      :        ...1.093016e-01 [+4.50]
#   ReML Iteration 5                      :        ...4.811044e-04 [+4.62]
# Inverting subject 1
#   ReML Iteration 1                      :        ...2.459539e+03 [+4.12]
#   ReML Iteration 2                      :        ...2.924548e+02 [+4.25]
#   ReML Iteration 3                      :        ...1.169796e+01 [+4.38]
#   ReML Iteration 4                      :        ...1.093016e-01 [+4.50]
#   ReML Iteration 5                      :        ...4.811044e-04 [+4.62]
# Percent variance explained 40.32 (1.26)
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 60
#           hpf: 90
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 0
#       PostMax: [65582x1 double]
#             A: [0x71 double]
#            Ip: [1x512 double]
#             M: [65582x44 double]
#             J: {[65582x4 double]}
#             L: [44x65582 double]
#            qC: [65582x1 double]
#         tempU: [240x240 double]
#             V: [240x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[44x71 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x178 double]
#            Ic: {[1x71 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x240 double]
#            ID: 392.9232
#             F: 8.7641e+05
#            R2: 40.3170
#            VE: 1.2552
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 60
#           hpf: 90
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 8.7641e+05
#       PostMax: [65582x1 double]
#             A: [0x71 double]
#            Ip: [1x512 double]
#             M: [65582x44 double]
#             J: {[65582x4 double]}
#             L: [44x65582 double]
#            qC: [65582x1 double]
#         tempU: [240x240 double]
#             V: [240x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[44x71 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x178 double]
#            Ic: {[1x71 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x240 double]
#            ID: 392.9232
#             F: 8.7641e+05
#            R2: 40.3170
#            VE: 1.2552
#
# 06-Apr-2026 13:05:06 - Done    'Source inversion, iterative'
# 06-Apr-2026 13:05:06 - Done
#
# Smoothing /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/multilayer.2.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '/home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat'
#
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using 0 spatial modes
#
# Preparing modes file  block 1 of 1 for 73 training and 0 test chans
#
#  saving spatial mode file /home/bonaiuto/laminar_opm/OPM-LMN.260209/opm/proc/S01_CZZ/spm_R3_epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
#
#
# ------------------------------------------------------------------------
# 06-Apr-2026 13:05:10 - Running job #1
# ------------------------------------------------------------------------
# 06-Apr-2026 13:05:10 - Running 'Source inversion, iterative'
# Auto selecting number of spatial modes
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm_R3_epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.6006    0.5557
#     0.0506    0.6511
#
#  - done
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using 46 spatial modesNumber of samples 1000
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 2.70 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.367499e+03 [+4.12]
#   ReML Iteration 2                      :        ...4.479808e+02 [+4.25]
#   ReML Iteration 3                      :        ...3.054332e+01 [+4.38]
#   ReML Iteration 4                      :        ...1.013406e-01 [+4.50]
#   ReML Iteration 5                      :        ...5.384932e-05 [+4.62]
# Inverting subject 1
#   ReML Iteration 1                      :        ...2.367499e+03 [+4.12]
#   ReML Iteration 2                      :        ...4.479808e+02 [+4.25]
#   ReML Iteration 3                      :        ...3.054332e+01 [+4.38]
#   ReML Iteration 4                      :        ...1.013406e-01 [+4.50]
#   ReML Iteration 5                      :        ...5.384932e-05 [+4.62]
# Percent variance explained 39.06 (1.05)
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 60
#           hpf: 90
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 0
#       PostMax: [65582x1 double]
#             A: [0x73 double]
#            Ip: [1x512 double]
#             M: [65582x46 double]
#             J: {[65582x4 double]}
#             L: [46x65582 double]
#            qC: [65582x1 double]
#         tempU: [240x240 double]
#             V: [240x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[46x73 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x73 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x240 double]
#            ID: 447.2232
#             F: 9.2664e+05
#            R2: 39.0571
#            VE: 1.0530
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 60
#           hpf: 90
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 9.2664e+05
#       PostMax: [65582x1 double]
#             A: [0x73 double]
#            Ip: [1x512 double]
#             M: [65582x46 double]
#             J: {[65582x4 double]}
#             L: [46x65582 double]
#            qC: [65582x1 double]
#         tempU: [240x240 double]
#             V: [240x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[46x73 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x73 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x240 double]
#            ID: 447.2232
#             F: 9.2664e+05
#            R2: 39.0571
#            VE: 1.0530
#
# 06-Apr-2026 13:05:34 - Done    'Source inversion, iterative'
# 06-Apr-2026 13:05:34 - Done
#
# Smoothing /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/multilayer.2.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '/home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat'
#
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using 0 spatial modes
#
# Preparing modes file  block 1 of 1 for 72 training and 0 test chans
#
#  saving spatial mode file /home/bonaiuto/laminar_opm/OPM-LMN.260209/opm/proc/S01_CZZ/spm_R4_epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
#
#
# ------------------------------------------------------------------------
# 06-Apr-2026 13:05:36 - Running job #1
# ------------------------------------------------------------------------
# 06-Apr-2026 13:05:36 - Running 'Source inversion, iterative'
# Auto selecting number of spatial modes
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm_R4_epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.6006    0.5557
#     0.0506    0.6511
#
#  - done
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using 43 spatial modesNumber of samples 1000
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 2.81 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.870491e+03 [+4.12]
#   ReML Iteration 2                      :        ...2.783233e+02 [+4.25]
#   ReML Iteration 3                      :        ...4.348307e+00 [+4.38]
#   ReML Iteration 4                      :        ...3.211696e-02 [+4.50]
#   ReML Iteration 5                      :        ...2.443938e-04 [+4.62]
# Inverting subject 1
#   ReML Iteration 1                      :        ...2.870491e+03 [+4.12]
#   ReML Iteration 2                      :        ...2.783233e+02 [+4.25]
#   ReML Iteration 3                      :        ...4.348307e+00 [+4.38]
#   ReML Iteration 4                      :        ...3.211696e-02 [+4.50]
#   ReML Iteration 5                      :        ...2.443938e-04 [+4.62]
# Percent variance explained 46.92 (1.32)
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 60
#           hpf: 90
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 0
#       PostMax: [65582x1 double]
#             A: [0x72 double]
#            Ip: [1x512 double]
#             M: [65582x43 double]
#             J: {[65582x4 double]}
#             L: [43x65582 double]
#            qC: [65582x1 double]
#         tempU: [240x240 double]
#             V: [240x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[43x72 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x72 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x240 double]
#            ID: 400.4997
#             F: 8.6692e+05
#            R2: 46.9226
#            VE: 1.3178
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 60
#           hpf: 90
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 8.6692e+05
#       PostMax: [65582x1 double]
#             A: [0x72 double]
#            Ip: [1x512 double]
#             M: [65582x43 double]
#             J: {[65582x4 double]}
#             L: [43x65582 double]
#            qC: [65582x1 double]
#         tempU: [240x240 double]
#             V: [240x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[43x72 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x72 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x240 double]
#            ID: 400.4997
#             F: 8.6692e+05
#            R2: 46.9226
#            VE: 1.3178
#
# 06-Apr-2026 13:05:52 - Done    'Source inversion, iterative'
# 06-Apr-2026 13:05:52 - Done
#
# Smoothing /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/multilayer.2.ds.link_vector.fixed.gii
#
# smoothmeshname =
#
#     '/home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat'
#
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Removed 0 bad channels
#
# Taking random selections of 0.00 percent of channels
# Using 0 spatial modes
#
# Preparing modes file  block 1 of 1 for 70 training and 0 test chans
#
#  saving spatial mode file /home/bonaiuto/laminar_opm/OPM-LMN.260209/opm/proc/S01_CZZ/spm_R5_epo_testmodes.mat
# SPM, version dev (standalone)
# MATLAB, version 9.6.0.1472908 (R2019a) Update 9
#  ___  ____  __  __
# / __)(  _ \(  \/  )
# \__ \ )___/ )    (   Statistical Parametric Mapping
# (___/(__)  (_/\/\_)  SPM - https://www.fil.ion.ucl.ac.uk/spm/
#
#
#
# ------------------------------------------------------------------------
# 06-Apr-2026 13:05:55 - Running job #1
# ------------------------------------------------------------------------
# 06-Apr-2026 13:05:55 - Running 'Source inversion, iterative'
# Auto selecting number of spatial modes
# Loading spatial modes from file
# Using testchans defined in spatial modes file
#
# gainname =
#
#     'SPMgainmatrix_spm_R5_epo_1.mat'
#
# Checking leadfieldsReseting random number seed ! and then generating random patch centres
# patchiter 1/1
# Checking leadfields
# ans =
#
#     0.6006    0.5557
#     0.0506    0.6511
#
#  - done
#
# Found smoothfile /home/bonaiuto/laminar_opm/OPM-LMN.260209/anat/fs/S01_CZZ/surf/laminar/FWHM5.00_multilayer.2.ds.link_vector.fixed.mat, not recomputing
# Warning: Variable 'M' not found.
#  - done
# Optimising and aligning spatial modes ...
# Using 41 spatial modesNumber of samples 1000
# Fixed number of temporal modes
# Using 4 temporal modes, accounting for 2.94 percent average variance
# NB smooth EBB algorithm !
# Using 1 spatial source priors provided
#   ReML Iteration 1                      :        ...2.919736e+03 [+4.12]
#   ReML Iteration 2                      :        ...2.697837e+02 [+4.25]
#   ReML Iteration 3                      :        ...1.783651e+00 [+4.38]
#   ReML Iteration 4                      :        ...5.484163e-03 [+4.50]
# Inverting subject 1
#   ReML Iteration 1                      :        ...2.919736e+03 [+4.12]
#   ReML Iteration 2                      :        ...2.697837e+02 [+4.25]
#   ReML Iteration 3                      :        ...1.783651e+00 [+4.38]
#   ReML Iteration 4                      :        ...5.484163e-03 [+4.50]
# Percent variance explained 51.57 (1.52)
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 60
#           hpf: 90
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 0
#       PostMax: [65582x1 double]
#             A: [0x70 double]
#            Ip: [1x512 double]
#             M: [65582x41 double]
#             J: {[65582x4 double]}
#             L: [41x65582 double]
#            qC: [65582x1 double]
#         tempU: [240x240 double]
#             V: [240x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[41x70 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x70 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x240 double]
#            ID: 371.7633
#             F: 8.2705e+05
#            R2: 51.5726
#            VE: 1.5167
#
# model evidences relative to maximum:
#
# ans =
#
#      0
#
#        priors: []
#          type: 'EBB'
#           woi: [0 3996]
#           Han: 0
#           lpf: 60
#           hpf: 90
#     mergeflag: 0
#            Np: 512
#            Nm: []
#            Nt: 4
#        smooth: 5
#       nlayers: 1
#      modality: 'MEG'
#          allF: 8.2705e+05
#       PostMax: [65582x1 double]
#             A: [0x70 double]
#            Ip: [1x512 double]
#             M: [65582x41 double]
#             J: {[65582x4 double]}
#             L: [41x65582 double]
#            qC: [65582x1 double]
#         tempU: [240x240 double]
#             V: [240x4 double]
#            qV: [1000x1000 double]
#             T: [1000x4 double]
#             U: {[41x70 double]}
#            Is: [1x65582 double]
#            It: [1x1000 double]
#            Ik: [1x180 double]
#            Ic: {[1x70 double]}
#            Nd: 65582
#           pst: [1x1000 double]
#           dct: [1x240 double]
#            ID: 371.7633
#             F: 8.2705e+05
#            R2: 51.5726
#            VE: 1.5167
#
# 06-Apr-2026 13:06:28 - Done    'Source inversion, iterative'
# 06-Apr-2026 13:06:28 - Done

# %%
laminar_t_statistic, laminar_p_value, df, gamma_roi_idx = roi_power_comparison_multi(
    data_files,
    gamma_exp_woi,
    gamma_base_woi,
    80,
    surf_set_bilam,
    roi_idx=v1_roi_idx,
    roi_mode="restrict_threshold",
    chunk_size=100
)
print(f"t({df})={laminar_t_statistic}, p={laminar_p_value}")

gamma_pial_power = load_layer_power_multi(
    data_files, 
    gamma_exp_woi,
    gamma_base_woi, 
    surf_set_bilam,
    gamma_roi_idx,
    chunk_size=100
)
gamma_layer_power=np.zeros(surf_set_bilam.get_vertices_per_layer())
gamma_layer_power[gamma_roi_idx]=gamma_pial_power
v_colors, c_map = color_map(
    gamma_layer_power, 
    "RdYlBu_r", 
    -np.max(np.abs(gamma_layer_power)), 
    np.max(np.abs(gamma_layer_power))
)
v_colors_thresh = np.zeros((v_colors.shape[0], 4))
v_colors_thresh[:, :3] = v_colors
v_colors_thresh[np.abs(gamma_layer_power)>0, -1] = 255
plot = show_surface(
    surf_set_bilam,
    layer_name="inflated",
    stage="ds",
    vertex_colors=v_colors_thresh,
    info=True,
    camera_view=cam_view
)

gamma_pial_bc_power, gamma_white_bc_power, time = load_roi_power_ts_multi(
    data_files, 
    gamma_base_woi, 
    surf_set_bilam, 
    gamma_roi_idx, 
    chunk_size=100
)
col_r = plt.cm.cool(np.linspace(0, 1, num=2))
roi_pial_bc_power = np.mean(gamma_pial_bc_power, axis=0)
roi_white_bc_power = np.mean(gamma_white_bc_power, axis=0)
m_pial_bc_power = np.mean(roi_pial_bc_power, axis=-1)
m_white_bc_power = np.mean(roi_white_bc_power, axis=-1)
plt.figure()
plt.plot(time-1000, m_pial_bc_power, label="pial", color=col_r[0, :])
plt.plot(time-1000, m_white_bc_power, label="white matter", color=col_r[1, :])
plt.axvline(0, color="k", linestyle="--")
plt.axvline(2000, color="k", linestyle="--")
plt.axvline(2500, color="k", linestyle="--")
plt.xlim([-1000, 3000])
plt.xlabel("Time (ms)")
plt.ylabel("$\\Delta$ power")
plt.legend()

exp_t_idx = (time >= gamma_exp_woi[0]) & (time <= gamma_exp_woi[1])
gamma_t_stats=[]
for x in range(len(gamma_roi_idx)):
    roi_pial_bc = gamma_pial_bc_power[x, :, :]
    roi_pial_bc = np.mean(roi_pial_bc[exp_t_idx, :], axis=0)

    roi_white_bc = gamma_white_bc_power[x, :, :]
    roi_white_bc = np.mean(roi_white_bc[exp_t_idx, :], axis=0)

    v_t_stat, v_dof, v_p = ttest_rel_corrected(
        np.abs(roi_pial_bc) - np.abs(roi_white_bc),
        axis=-1,
    )
    gamma_t_stats.append(v_t_stat)
plt.figure()
plt.hist(gamma_t_stats, 50, density=True)
plt.axvline(0, color="k", linestyle="--")
xl = plt.xlim()
xlim = [-np.max(np.abs(xl)), np.max(np.abs(xl))]
plt.xlim(xlim)
plt.xlabel("t statistic (pial-white)")
plt.ylabel("Density")
# Out:
# t(895)=10.747090714523235, p=2.013836864198403e-25
# Output()
# 32791 vertices
# Text(0, 0.5, 'Density')

# %%
# spm.terminate()
